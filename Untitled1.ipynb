# %% [markdown]
# <a href="https://colab.research.google.com/github/Aweiez/learningpythonb/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###2024-329筆記

# %% [markdown]
# ###使用Pillow做影像處理

# %% [markdown]
# ###讀取影像

# %%
from PIL import Image

# %%
img = Image.open('雞')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=481x519>

# %%
img.size
# Out:
# (481, 519)

# %%
img.thumbnail((200,200))

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=185x200>

# %%
img.mode
# Out:
# 'RGBA'

# %%
img.format
# Out:
# 'PNG'

# %% [markdown]
# ###changing color

# %%
img.resize?

# %%
img.resize((200,200))
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200>

# %%
img.rotate(45,)
# Out:
# <PIL.Image.Image image mode=RGBA size=185x200>

# %%
img.mode
# Out:
# 'RGBA'

# %%
r,g,b, a=img.split()
Image.merge('RGB',(b,g,r))
# Out:
# <PIL.Image.Image image mode=RGB size=185x200>

# %%
img.crop((50,0,150,100))
# Out:
# <PIL.Image.Image image mode=RGBA size=100x100>

# %%
img.paste(img,(50,0))
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=185x200>
